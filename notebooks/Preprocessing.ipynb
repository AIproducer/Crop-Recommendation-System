# %%
import pandas as pd

df = pd.read("../data/raw/Crop_recommendation.csv")

X, y = split_features_target(df)

y_encoded, encoder = encode_labels(y)

X_train, X_test, y_train, y_test = split_dataset(X, y)

print(X_train.shape)
print(X_test.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       1 import pandas as pd
#       3 df = pd.read_csv("../data/raw/Crop_recommendation.csv")
# ----> 5 X, y = split_features_target(df)
#       7 y_encoded, encoder = encode_labels(y)
#       9 X_train, X_test, y_train, y_test = split_dataset(X, y)
#
# NameError: name 'split_features_target' is not defined
